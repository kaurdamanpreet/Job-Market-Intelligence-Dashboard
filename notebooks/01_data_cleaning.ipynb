# %%
import pandas as pd

# Load dataset
df = pd.read_csv("raw_jobs_data.csv")

# Preview data
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# 2                 GB            50               GB            M
# 3                 HN             0               HN            S
# 4                 US            50               US            L

# %% [markdown]
# Filter Canada-only jobs

# %%
df_canada = df[df["company_location"] == "CA"]

# %% [markdown]
# Select relevant columns

# %%
df_canada = df_canada[
    [
        "job_title",
        "experience_level",
        "employment_type",
        "salary_in_usd",
        "work_year",
        "company_location"
    ]
]

# %%
Clean job titles (normalize roles)

# %%
def normalize_job_title(title):
    title = title.lower()
    if "data analyst" in title:
        return "Data Analyst"
    elif "data scientist" in title:
        return "Data Scientist"
    elif "machine learning" in title or "ai" in title:
        return "AI / ML Engineer"
    elif "business analyst" in title:
        return "Business Analyst"
    else:
        return "Other"

df_canada["job_role"] = df_canada["job_title"].apply(normalize_job_title)

# %% [markdown]
# Convert salary USD → CAD
#
# (Using 1 USD = 1.35 CAD — realistic and interview-safe)

# %%
USD_TO_CAD = 1.35
df_canada["salary_cad"] = df_canada["salary_in_usd"] * USD_TO_CAD

# %% [markdown]
# Map experience levels

# %%
experience_map = {
    "EN": "Entry-level",
    "MI": "Mid-level",
    "SE": "Senior-level",
    "EX": "Executive"
}

df_canada["experience_level"] = df_canada["experience_level"].map(experience_map)

# %% [markdown]
# Remove nulls & duplicates

# %%
df_canada.dropna(inplace=True)
df_canada.drop_duplicates(inplace=True)

# %% [markdown]
# Final check

# %%
df_canada.info()
df_canada.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28 entries, 29 to 601
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   job_title         28 non-null     object
#  1   experience_level  28 non-null     object
#  2   employment_type   28 non-null     object
#  3   salary_in_usd     28 non-null     int64
#  4   work_year         28 non-null     int64
#  5   company_location  28 non-null     object
#  6   job_role          28 non-null     object
#  7   salary_cad        28 non-null     float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 2.0+ KB
#                     job_title experience_level employment_type  salary_in_usd  \
# 29   Machine Learning Manager     Senior-level              FT         117104
# 82     Applied Data Scientist        Mid-level              FT          54238
# 106        Research Scientist        Mid-level              FT         187442
# 152            Data Scientist        Mid-level              FT          75774
# 155     Data Science Engineer     Senior-level              FT         127221
#
#      work_year company_location          job_role  salary_cad
# 29        2020               CA  AI / ML Engineer   158090.40
# 82        2021               CA    Data Scientist    73221.30
# 106       2021               CA             Other   253046.70
# 152       2021               CA    Data Scientist   102294.90
# 155       2021               CA             Other   171748.35

# %% [markdown]
# Export clean dataset for Tableau

# %%
df_canada.to_csv("cleaned_canada_jobs.csv", index=False)
